# %% [markdown]
# # Part 1: Processing Real Text

# %% [markdown]
# *Just reading chapter 3 and a short lecture*
#
# *For help with regular expressions, unicode, tokenization, and segmentation, refer to chapter 3*

# %%
import nltk, re, pprint
from nltk import word_tokenize
from urllib import request

# Required for word_tokenize to work
nltk.download("punkt_tab")

url = "http://www.gutenberg.org/files/2554/2554-0.txt"
response = request.urlopen(url)
raw = response.read().decode("utf8")

print("raw:", type(raw))
print("length:", len(raw))
print("slice:", raw[:75])

tokens = word_tokenize(raw)
print("token length:", len(tokens))
print("part of tokens:", tokens[:10])

text = nltk.Text(tokens)
text.collocations()

url = "http://news.bbc.co.uk/2/hi/health/2284783.stm"
html = request.urlopen(url).read().decode("utf8")
html[:60]

wordlist = [w for w in nltk.corpus.words.words("en") if w.islower()]

# Matches words of any length
# Use "^..j..t..$" if you wanna find, e.g., words of exactly length 8 with j and t at those places
[w for w in wordlist if re.search("..j..t..", w)]
# Out:
# [nltk_data] Downloading package punkt_tab to /Users/Adam/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# raw: <class 'str'>
# length: 1135213
# slice: *** START OF THE PROJECT GUTENBERG EBOOK 2554 ***
#
#
#
#
# CRIME AND PUNISHMENT
#
# token length: 253687
# part of tokens: ['*', '*', '*', 'START', 'OF', 'THE', 'PROJECT', 'GUTENBERG', 'EBOOK', '2554']
# Katerina Ivanovna; Pyotr Petrovitch; Pulcheria Alexandrovna; Avdotya
# Romanovna; Rodion Romanovitch; Marfa Petrovna; Sofya Semyonovna; old
# woman; Porfiry Petrovitch; Amalia Ivanovna; great deal; young man;
# Nikodim Fomitch; Ilya Petrovitch; Andrey Semyonovitch; Hay Market;
# Dmitri Prokofitch; Good heavens; police station; head clerk
# ['abjectedness',
#  'abjection',
#  'abjective',
#  'abjectly',
#  'abjectness',
#  'adjection',
#  'adjectional',
#  'adjectival',
#  'adjectivally',
#  'adjective',
#  'adjectively',
#  'adjectivism',
#  'adjectivitis',
#  'adjustable',
#  'adjustably',
#  'adjustage',
# ...

# %% [markdown]
# # Part 2: Community Detection
