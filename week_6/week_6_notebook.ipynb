# %% [markdown]
# # Part 1: Introduction to Natural Language Processing

# %% [markdown]
# _Just a short lecture_

# %% [markdown]
# # Part 2: Installation and Basics of NLTK

# %%
import nltk

# nltk.download("book")
from nltk.book import *

# Exercises from Chapter 1 (NLPP)

# Section 1.1
print("Concordance:")
text1.concordance("monstrous")
text4.concordance("people")

print()

print("Similar:")
text1.similar("monstrous")
text2.similar("monstrous")
text4.similar("people")

print()

print("Common contexts:")
text2.common_contexts(["monstrous", "very"])
text4.common_contexts(["people", "government"])
text4.common_contexts(["people", "duty"])

print()

print("Dispersion plots")
text4.dispersion_plot(
    [
        "citizens",
        "democracy",
        "freedom",
        "duties",
        "America",
        "liberty",
        "constitution",
    ]
)

text3.dispersion_plot(["Adam", "Eve", "God", "serpent", "tree", "good", "evil", "sin"])

print()

# Lexical diversity describes the variety of unique words in a text
# It describes how word usage, and thus changes in language use, changes over time

print("Collocations:")
text3.collocations()

# Collocations are expressions of multiple words that often occur together
# Bigrams are sequences of adjacent words, letters, etc., i.e., written together

print()

# Section 1.3

# Frequency distribution for Text 2
print("Frequency distribution:")
fdist2 = FreqDist(text2)
print(fdist2)
print(fdist2.most_common(75))
print("Occurences of love:", fdist2["love"])


# Lexical diversity and occurence of word in percent
def lexical_diversity(text):
    return len(set(text)) / len(text)


def percentage(count, total):
    return 100 * count / total


# Section 1.8 (some of the exercises from 2 through 12)
print("hundred-letter string combinations with 26 letters", 26**100)

py_list = ["Monty", "Python"]
print(py_list * 20)
sent1 = ["Call", "me", "Ishmael", "."]
print(3 * sent1)

print()

print("distinct words in text2,", sorted(set(text2)))

print()

text2.dispersion_plot(
    [
        "Elinor",
        "Marianne",
        "Edward",
        "Willoughby",
    ]
)
# Out:
# Concordance:
# Displaying 11 of 11 matches:
# ong the former , one was of a most monstrous size . ... This came towards us ,
# ON OF THE PSALMS . " Touching that monstrous bulk of the whale or ork we have r
# ll over with a heathenish array of monstrous clubs and spears . Some were thick
# d as you gazed , and wondered what monstrous cannibal and savage could ever hav
# that has survived the flood ; most monstrous and most mountainous ! That Himmal
# they might scout at Moby Dick as a monstrous fable , or still worse and more de
# th of Radney .'" CHAPTER 55 Of the Monstrous Pictures of Whales . I shall ere l
# ing Scenes . In connexion with the monstrous pictures of whales , I am strongly
# ere to enter upon those still more monstrous stories of them which are to be fo
# ght have been rummaged out of this monstrous cabinet there is no telling . But
# of Whale - Bones ; for Whales of a monstrous size are oftentimes cast up dead u
# Displaying 25 of 602 matches:
# ...
