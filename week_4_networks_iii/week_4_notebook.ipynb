# %% [markdown]
# # Part 1: Download Wikipedia Pages

# %%
import requests, json, re, networkx as nx, os
from bs4 import BeautifulSoup

# Wikipedia API endpoint
url = "https://en.wikipedia.org/w/api.php"

# Define parameters
params = {
    "action": "query",
    "titles": "List_of_mainstream_rock_performers",
    "prop": "revisions",
    "rvprop": "content",
    "format": "json",
    "rvslots": "main",
}

# Set custom header (optional but polite)
headers = {"User-Agent": "MyWikipediaClient/1.0 (example@example.com)"}

# GET request
response = requests.get(url, headers=headers, params=params)

# Query URL with params
query = response.url
print("Query URL:", query)

# Check status code
status = response.status_code
# print("Status code:", status)
print("Query:", response)

# Page data
content = response.content
# print(content)

# Convert response to JSON
data = response.json()

# Pretty-print JSON
# print("JSON:")
# print(json.dumps(data, indent=2))

# Scrape web page with BeautifulSoup
# soup = BeautifulSoup(response.content, "html.parser")

# Display scraped data
# print(soup.prettify())
# print(list(soup.children))

# Page data
# pages = content["query"]["pages"]
# page = next(iter(pages.values()))
# content = page["revisions"][0]["*"]

# Wikitext
page = next(iter(data["query"]["pages"].values()))
# print(page)
wikitext = page["revisions"][0]["slots"]["main"]["*"]
# print(wikitext)

# Regex to extract artist names from wiki links
artists = re.findall(r"\[\[([^\]|#]+)", wikitext)

# Remove duplicates and sort
artists = sorted(set(artists))


# Number of matches and first 20
print("Number of matches:", len(artists))
print(artists[:20])

# Save to file
with open("rock_artists.txt", "w", encoding="utf-8") as f:
    f.write(wikitext)
# Out:
# Query URL: https://en.wikipedia.org/w/api.php?action=query&titles=List_of_mainstream_rock_performers&prop=revisions&rvprop=content&format=json&rvslots=main
# Query: <Response [200]>
# Number of matches: 492
# ['10 Years (band)', '10cc', '3 Doors Down', '311 (band)', '38 Special (band)', 'A Perfect Circle', 'ABBA', 'AC/DC', 'AFI (band)', 'Accept (band)', 'Adam Ant', 'Aerosmith', 'Air Supply', 'Alanis Morissette', 'Alice Cooper', 'Alice Cooper (band)', 'Alice in Chains', 'AllMusic', 'Alter Bridge', 'Ambrosia (band)']

# %%
print(f"Found {len(artists)} artists")

# Create output directory
os.makedirs("rock_artists", exist_ok=True)

# Excludes non-artist wikilinks
exclude_prefixes = (
    "Category:", "Template:", "File:", "Wikipedia:",
    "Help:", "Portal:", "Talk:", "Book:", "Draft:"
)

manual_excludes = [
    "AllMusic", "Rolling Stone", "rock music", "Heavy Metal", 
    "Punk Rock", "Alternative Rock", "Classic Rock", "singles",
    "album charts", "streaming", "downloads", "airplay"
]
artist = [
    link for link in artists
    if link not in manual_excludes and not link.startswith(exclude_prefixes)
]

# Loop through artists and download their wikitext
for i, artist in enumerate(artists):
    # Replace spaces with underscores for API titles
    artist_title = artist.replace(" ", "_")

    params = {
        "action": "query",
        "titles": artist_title,
        "prop": "revisions",
        "rvprop": "content",
        "format": "json",
        "rvslots": "main",
    }

    try:
        res = requests.get(url, headers=headers, params=params)
        res.raise_for_status()
        artist_data = res.json()

        # Extract wikitext
        page = next(iter(artist_data["query"]["pages"].values()))
        if "revisions" not in page:
            print(f"Skipping {artist} (no revisions found)")
            continue

        text = page["revisions"][0]["slots"]["main"]["*"]

        # Save to file
        safe_name = re.sub(r'[\\/:"*?<>|]+', "_", artist_title)
        file_path = os.path.join("rock_artists", f"{safe_name}.txt")
        with open(file_path, "w", encoding="utf-8") as f:
            f.write(text)

        print(f"Saved {artist} ({i+1}/{len(artists)})")

    except Exception as e:
        print(f"Error processing {artist}: {e}")
        continue

print("Done")
# Out:
# Found 492 artists
# Saved 10 Years (band) (1/492)
# Saved 10cc (2/492)
# Saved 3 Doors Down (3/492)
# Saved 311 (band) (4/492)
# Saved 38 Special (band) (5/492)
# Saved A Perfect Circle (6/492)
# Saved ABBA (7/492)
# Saved AC/DC (8/492)
# Saved AFI (band) (9/492)
# Saved Accept (band) (10/492)
# Saved Adam Ant (11/492)
# Saved Aerosmith (12/492)
# Saved Air Supply (13/492)
# Saved Alanis Morissette (14/492)
# Saved Alice Cooper (15/492)
# Saved Alice Cooper (band) (16/492)
# Saved Alice in Chains (17/492)
# Saved AllMusic (18/492)
# Saved Alter Bridge (19/492)
# Saved Ambrosia (band) (20/492)
# Saved America (band) (21/492)
# Saved Anthrax (American band) (22/492)
# Saved April Wine (23/492)
# Saved Arcade Fire (24/492)
# Saved Arctic Monkeys (25/492)
# Saved Asia (band) (26/492)
# Saved Audioslave (27/492)
# Saved Avenged Sevenfold (28/492)
# Saved Avril Lavigne (29/492)
# Saved Awolnation (30/492)
# Saved Bachman–Turner Overdrive (31/492)
# Saved Bad Company (32/492)
# Saved Badfinger (33/492)
# Saved Barenaked Ladies (34/492)
# Saved Bay City Rollers (35/492)
# Saved Beastie Boys (36/492)
# Saved Beck (37/492)
# Saved Bee Gees (38/492)
# Saved Ben Folds Five (39/492)
# Saved Bill Haley & His Comets (40/492)
# Saved Billy Idol (41/492)
# Saved Billy Joel (42/492)
# Saved Billy Squier (43/492)
# Saved Billy Talent (44/492)
# Saved Black Sabbath (45/492)
# Saved Black Stone Cherry (46/492)
# Saved Black Veil Brides (47/492)
# Saved Blink-182 (48/492)
# Saved Blondie (band) (49/492)
# Saved Bloodhound Gang (50/492)
# Saved Blue October (51/492)
# Saved Blue Öyster Cult (52/492)
# Saved Blues Traveler (53/492)
# Saved Blur (band) (54/492)
# Saved Bo Diddley (55/492)
# Saved Bob Dylan (56/492)
# Saved Bob Seger (57/492)
# Saved Bon Jovi (58/492)
# Saved Boston (band) (59/492)
# Saved Bowling for Soup (60/492)
# Saved Boys Like Girls (61/492)
# Saved Bread (band) (62/492)
# Saved Breaking Benjamin (63/492)
# Saved Bring Me the Horizon (64/492)
# Saved Bruce Springsteen (65/492)
# Saved Bryan Adams (66/492)
# Saved Bryan Ferry (67/492)
# Saved Buckcherry (68/492)
# Saved Buddy Holly (69/492)
# Saved Bullet for My Valentine (70/492)
# Saved Bush (British band) (71/492)
# Saved Cage the Elephant (72/492)
# Saved Cake (band) (73/492)
# Saved Canned Heat (74/492)
# Saved Category:Lists of rock musicians (75/492)
# Saved Category:Lists of rock musicians by subgenre (76/492)
# Saved Catfish and the Bottlemen (77/492)
# Saved Charlie Daniels (78/492)
# Saved Cheap Trick (79/492)
# Saved Chevelle (band) (80/492)
# Saved Chicago (band) (81/492)
# Saved Chris Cornell (82/492)
# Saved Chris Rea (83/492)
# Saved Chris de Burgh (84/492)
# Saved Christopher Cross (85/492)
# Saved Chubby Checker (86/492)
# Saved Chuck Berry (87/492)
# Saved Cinderella (band) (88/492)
# Saved Coheed and Cambria (89/492)
# Saved Cold Chisel (90/492)
# Saved Coldplay (91/492)
# Saved Collective Soul (92/492)
# Saved Counting Crows (93/492)
# Saved Crash Test Dummies (94/492)
# Saved Cream (band) (95/492)
# Saved Creed (band) (96/492)
# Saved Creedence Clearwater Revival (97/492)
# Saved Crosby, Stills, Nash & Young (98/492)
# Saved Crowded House (99/492)
# Saved Dallas Green (musician) (100/492)
# Saved Damn Yankees (band) (101/492)
# Saved Dan Fogelberg (102/492)
# Saved Dashboard Confessional (103/492)
# Saved Daughtry (band) (104/492)
# Saved Dave Matthews Band (105/492)
# Saved David Bowie (106/492)
# Saved Days of the New (107/492)
# Saved Death Cab for Cutie (108/492)
# Saved Deep Purple (109/492)
# Saved Def Leppard (110/492)
# Saved Deftones (111/492)
# Saved Depeche Mode (112/492)
# Saved Dio (band) (113/492)
# Saved Dire Straits (114/492)
# Saved Disturbed (band) (115/492)
# Saved Don Henley (116/492)
# Saved Donovan (117/492)
# Saved Dr. Hook & the Medicine Show (118/492)
# Saved Dropkick Murphys (119/492)
# Saved Drowning Pool (120/492)
# Saved Duane Eddy (121/492)
# Saved Duran Duran (122/492)
# Saved Eagles (band) (123/492)
# Saved Echo & the Bunnymen (124/492)
# Saved Eddie Cochran (125/492)
# Saved Eddie Money (126/492)
# Saved Edgar Winter (127/492)
# Saved Electric Light Orchestra (128/492)
# Saved Elton John (129/492)
# Saved Elvis Costello (130/492)
# Saved Elvis Presley (131/492)
# Saved Emerson, Lake & Palmer (132/492)
# Saved England Dan & John Ford Coley (133/492)
# Saved Eric Clapton (134/492)
# Saved Europe (band) (135/492)
# Saved Evanescence (136/492)
# Saved Everclear (band) (137/492)
# Saved Everlast (138/492)
# Saved Extreme (band) (139/492)
# Saved Faces (band) (140/492)
# Saved Faith No More (141/492)
# Saved Fall Out Boy (142/492)
# Saved Fats Domino (143/492)
# Saved Filter (band) (144/492)
# Saved Finger Eleven (145/492)
# Saved FireHouse (146/492)
# Saved Five Finger Death Punch (147/492)
# Saved Five for Fighting (148/492)
# Saved Fleetwood Mac (149/492)
# Saved Flogging Molly (150/492)
# Saved Florence and the Machine (151/492)
# Saved Flyleaf (band) (152/492)
# Saved Foals (band) (153/492)
# Saved Foo Fighters (154/492)
# Saved Foreigner (band) (155/492)
# Saved Foster the People (156/492)
# Saved Frank Zappa (157/492)
# Saved Franz Ferdinand (band) (158/492)
# Saved Fuel (band) (159/492)
# Saved Fun (band) (160/492)
# Saved Funkadelic (161/492)
# Saved Garbage (band) (162/492)
# Saved Gary Glitter (163/492)
# Saved Gene Vincent (164/492)
# Saved Genesis (band) (165/492)
# Saved George Harrison (166/492)
# Saved George Thorogood (167/492)
# Saved Ghost (Swedish band) (168/492)
# Saved Gin Blossoms (169/492)
# Saved Glenn Frey (170/492)
# Saved Godsmack (171/492)
# Saved Golden Earring (172/492)
# Saved Goo Goo Dolls (173/492)
# Saved Good Charlotte (174/492)
# Saved Grand Funk Railroad (175/492)
# Saved Grateful Dead (176/492)
# Saved Great White (177/492)
# Saved Green Day (178/492)
# Saved Greta Van Fleet (179/492)
# Saved Guns N' Roses (180/492)
# Saved Halestorm (181/492)
# Saved Hall & Oates (182/492)
# Saved Harry Chapin (183/492)
# Saved Harry Nilsson (184/492)
# Saved Heart (band) (185/492)
# Saved Herman's Hermits (186/492)
# Saved Highly Suspect (187/492)
# Saved Hinder (188/492)
# Saved Hole (band) (189/492)
# Saved Hoobastank (190/492)
# Saved Hootie & the Blowfish (191/492)
# Saved Huey Lewis and the News (192/492)
# Saved INXS (193/492)
# Saved Ian Dury (194/492)
# Saved Icehouse (band) (195/492)
# Saved Iggy Pop (196/492)
# Saved Imagine Dragons (197/492)
# Saved Incubus (band) (198/492)
# Saved Interpol (band) (199/492)
# Saved Iron Maiden (200/492)
# Saved Jack White (201/492)
# Saved Jackson Browne (202/492)
# Saved James Blunt (203/492)
# Saved James Taylor (204/492)
# Saved Jane's Addiction (205/492)
# Saved Janis Joplin (206/492)
# Saved Jeff Buckley (207/492)
# Saved Jefferson Airplane (208/492)
# Saved Jefferson Starship (209/492)
# Saved Jerry Lee Lewis (210/492)
# Saved Jet (Australian band) (211/492)
# Saved Jethro Tull (band) (212/492)
# Saved Jim Croce (213/492)
# Saved Jimi Hendrix (214/492)
# Saved Jimmy Eat World (215/492)
# Saved Joan Jett (216/492)
# Saved Joe Cocker (217/492)
# Saved Joe Satriani (218/492)
# Saved Joe Walsh (219/492)
# Saved John Fogerty (220/492)
# Saved John Lennon (221/492)
# Saved John Mayall (222/492)
# Saved John Mayall & the Bluesbreakers (223/492)
# Saved John Mayer (224/492)
# Saved John Mellencamp (225/492)
# Saved Journey (band) (226/492)
# Saved Joy Division (227/492)
# Saved Judas Priest (228/492)
# Saved Kaiser Chiefs (229/492)
# Saved Kaleo (band) (230/492)
# Saved Kansas (band) (231/492)
# Saved Keane (band) (232/492)
# Saved Kenny Loggins (233/492)
# Saved Kid Rock (234/492)
# Saved Killswitch Engage (235/492)
# Saved Kings of Leon (236/492)
# Saved Kiss (band) (237/492)
# Saved Korn (238/492)
# Saved Lacuna Coil (239/492)
# Saved Lamb of God (band) (240/492)
# Saved Led Zeppelin (241/492)
# Saved Lenny Kravitz (242/492)
# Saved Lifehouse (band) (243/492)
# Saved Limp Bizkit (244/492)
# Saved Linda Ronstadt (245/492)
# Saved Linkin Park (246/492)
# Saved Little Richard (247/492)
# Saved Little River Band (248/492)
# Saved Live (band) (249/492)
# Saved Living Colour (250/492)
# Saved Lou Reed (251/492)
# Saved Loverboy (252/492)
# Saved Lynyrd Skynyrd (253/492)
# Saved Manfred Mann (254/492)
# Saved Manfred Mann (musician) (255/492)
# Saved Manfred Mann Chapter Three (256/492)
# Saved Manfred Mann's Earth Band (257/492)
# Saved Marilyn Manson (258/492)
# Saved Marilyn Manson (band) (259/492)
# Saved Matchbox Twenty (260/492)
# Saved Meat Loaf (261/492)
# Saved Megadeth (262/492)
# Saved Melissa Etheridge (263/492)
# Saved Men at Work (264/492)
# Saved Metallica (265/492)
# Saved Michael Martin Murphey (266/492)
# Saved Midnight Oil (267/492)
# Saved Mike and the Mechanics (268/492)
# Saved Mitch Ryder (269/492)
# Saved Modest Mouse (270/492)
# Saved Montgomery Gentry (271/492)
# Saved Morrissey (272/492)
# Saved Motörhead (273/492)
# Saved Mudvayne (274/492)
# Saved Mumford & Sons (275/492)
# Saved Muse (band) (276/492)
# Saved My Chemical Romance (277/492)
# Saved Mötley Crüe (278/492)
# Saved Neil Young (279/492)
# Saved New York Dolls (280/492)
# Saved Nickelback (281/492)
# Saved Nine Inch Nails (282/492)
# Saved Nirvana (band) (283/492)
# Saved No Doubt (284/492)
# Saved Oasis (band) (285/492)
# Saved Our Lady Peace (286/492)
# Saved Ozzy Osbourne (287/492)
# Saved P.O.D. (288/492)
# Saved Panic! at the Disco (289/492)
# Saved Pantera (290/492)
# Saved Papa Roach (291/492)
# Saved Paramore (292/492)
# Saved Parliament (band) (293/492)
# Saved Parliament-Funkadelic (294/492)
# Saved Pat Benatar (295/492)
# Saved Paul McCartney (296/492)
# Saved Paul McCartney and Wings (297/492)
# Saved Pearl Jam (298/492)
# Saved Peter Frampton (299/492)
# Saved Peter Gabriel (300/492)
# Saved Phil Collins (301/492)
# Saved Pink Floyd (302/492)
# Saved Pixies (band) (303/492)
# Saved Poison (American band) (304/492)
# Saved Pop Evil (305/492)
# Saved Primus (band) (306/492)
# Saved Puddle of Mudd (307/492)
# Saved Queen (band) (308/492)
# Saved Queens of the Stone Age (309/492)
# Saved Queensrÿche (310/492)
# Saved Quiet Riot (311/492)
# Saved R.E.M. (312/492)
# Saved REO Speedwagon (313/492)
# Saved Radiohead (314/492)
# Saved Rage Against the Machine (315/492)
# Saved Rainbow (rock band) (316/492)
# Saved Rammstein (317/492)
# Saved Ramones (318/492)
# Saved Ratt (319/492)
# Saved Red Hot Chili Peppers (320/492)
# Saved Ringo Starr (321/492)
# Saved Rise Against (322/492)
# Saved Ritchie Valens (323/492)
# Saved Rob Zombie (324/492)
# Saved Robert Plant (325/492)
# Saved Rod Stewart (326/492)
# Saved Roxy Music (327/492)
# Saved Roy Orbison (328/492)
# Saved Royal Blood (band) (329/492)
# Saved Run-DMC (330/492)
# Saved Rush (band) (331/492)
# Saved Saliva (band) (332/492)
# Saved Sam Fender (333/492)
# Saved Santana (band) (334/492)
# Saved Saving Abel (335/492)
# Saved Scorpions (band) (336/492)
# Saved Seether (337/492)
# Saved Sepultura (338/492)
# Saved Sex Pistols (339/492)
# Saved Shakin' Stevens (340/492)
# Saved Sheryl Crow (341/492)
# Saved Shinedown (342/492)
# Saved Silverchair (343/492)
# Saved Simon & Garfunkel (344/492)
# Saved Simple Minds (345/492)
# Saved Simple Plan (346/492)
# Saved Sixto Rodriguez (347/492)
# Saved Skid Row (American band) (348/492)
# Saved Skillet (band) (349/492)
# Saved Slade (350/492)
# Saved Slayer (351/492)
# Saved Slipknot (band) (352/492)
# Saved Sly and the Family Stone (353/492)
# Saved Small Faces (354/492)
# Saved Smash Mouth (355/492)
# Saved Smokie (band) (356/492)
# Saved Snow Patrol (357/492)
# Saved Social Distortion (358/492)
# Saved Sonic Youth (359/492)
# Saved Soundgarden (360/492)
# Saved Staind (361/492)
# Saved Starset (362/492)
# Saved Starship (band) (363/492)
# Saved Status Quo (band) (364/492)
# Saved Steely Dan (365/492)
# Saved Steppenwolf (band) (366/492)
# Saved Steve Miller Band (367/492)
# Saved Steve Vai (368/492)
# Saved Steve Winwood (369/492)
# Saved Stevie Nicks (370/492)
# Saved Stevie Ray Vaughan (371/492)
# Saved Sting (musician) (372/492)
# Saved Stone Sour (373/492)
# Saved Stone Temple Pilots (374/492)
# Saved Styx (band) (375/492)
# Saved Sublime (band) (376/492)
# Saved Sublime with Rome (377/492)
# Saved Sum 41 (378/492)
# Saved Supertramp (379/492)
# Saved Survivor (band) (380/492)
# Saved System of a Down (381/492)
# Saved T. Rex (band) (382/492)
# Saved Talking Heads (383/492)
# Saved Ted Nugent (384/492)
# Saved Ten Years After (385/492)
# Saved Tenacious D (386/492)
# Saved Tesla (band) (387/492)
# Saved The Alan Parsons Project (388/492)
# Saved The All-American Rejects (389/492)
# Saved The Allman Brothers Band (390/492)
# Saved The Animals (391/492)
# Saved The B-52's (392/492)
# Saved The Band (393/492)
# Saved The Bangles (394/492)
# Saved The Beach Boys (395/492)
# Saved The Beatles (396/492)
# Saved The Big Bopper (397/492)
# Saved The Black Crowes (398/492)
# Saved The Black Keys (399/492)
# Saved The Boxtones (400/492)
# Saved The Byrds (401/492)
# Saved The Cab (402/492)
# Saved The Cardigans (403/492)
# Saved The Cars (404/492)
# Saved The Clash (405/492)
# Saved The Cranberries (406/492)
# Saved The Cult (407/492)
# Saved The Cure (408/492)
# Saved The Dave Clark Five (409/492)
# Saved The Doobie Brothers (410/492)
# Saved The Doors (411/492)
# Saved The Everly Brothers (412/492)
# Saved The Fixx (413/492)
# Saved The Flaming Lips (414/492)
# Saved The Four Seasons (band) (415/492)
# Saved The Fray (416/492)
# Saved The Go-Go's (417/492)
# Saved The Guess Who (418/492)
# Saved The Hives (419/492)
# Saved The Hollies (420/492)
# Saved The J. Geils Band (421/492)
# Saved The Jam (422/492)
# Saved The Jesus and Mary Chain (423/492)
# Saved The Killers (424/492)
# Saved The Kinks (425/492)
# Saved The Lovin' Spoonful (426/492)
# Saved The Lumineers (427/492)
# Saved The Mamas & the Papas (428/492)
# Saved The Marshall Tucker Band (429/492)
# Saved The Monkees (430/492)
# Saved The Moody Blues (431/492)
# Saved The Mothers of Invention (432/492)
# Saved The Offspring (433/492)
# Saved The Outfield (434/492)
# Saved The Police (435/492)
# Saved The Presidents of the United States of America (band) (436/492)
# Saved The Pretenders (437/492)
# Saved The Pretty Reckless (438/492)
# Saved The Rolling Stones (439/492)
# Saved The Script (440/492)
# Saved The Smashing Pumpkins (441/492)
# Saved The Smiths (442/492)
# Saved The Stone Roses (443/492)
# Saved The Strokes (444/492)
# Saved The Sweet (445/492)
# Saved The Tragically Hip (446/492)
# Saved The Used (447/492)
# Saved The Velvet Underground (448/492)
# Saved The Verve (449/492)
# Saved The White Stripes (450/492)
# Saved The Who (451/492)
# Saved The Yardbirds (452/492)
# Saved The Zombies (453/492)
# Saved Theory of a Deadman (454/492)
# Saved Thin Lizzy (455/492)
# Saved Third Eye Blind (456/492)
# Saved Thirty Seconds to Mars (457/492)
# Saved Thousand Foot Krutch (458/492)
# Saved Three Days Grace (459/492)
# Saved Three Dog Night (460/492)
# Saved Tom Petty (461/492)
# Saved Tom Petty and the Heartbreakers (462/492)
# Saved Tommy James and the Shondells (463/492)
# Saved Tool (band) (464/492)
# Saved Toto (band) (465/492)
# Saved Tracy Chapman (466/492)
# Saved Traffic (band) (467/492)
# Saved Train (band) (468/492)
# Saved Traveling Wilburys (469/492)
# Saved Travis (band) (470/492)
# Saved Trivium (band) (471/492)
# Saved Twenty One Pilots (472/492)
# Saved Twisted Sister (473/492)
# Saved U2 (474/492)
# Saved UB40 (475/492)
# Saved Uriah Heep (band) (476/492)
# Saved Vampire Weekend (477/492)
# Saved Van Halen (478/492)
# Saved Van Morrison (479/492)
# Saved Van Zant (band) (480/492)
# Saved Velvet Revolver (481/492)
# Saved Volbeat (482/492)
# Saved W.A.S.P. (band) (483/492)
# Saved Warrant (American band) (484/492)
# Saved Weezer (485/492)
# Saved White Zombie (band) (486/492)
# Saved Whitesnake (487/492)
# Saved X (American band) (488/492)
# Saved X Ambassadors (489/492)
# Saved Yes (band) (490/492)
# Saved ZZ Top (491/492)
# Saved rock music (492/492)
# Done

# %%
# Step 1: Load the saved wikitext file (from the API step earlier)
with open("rock_artists.txt", "r", encoding="utf-8") as f:
    text = f.read()

# Step 2: Regex pattern for wiki-links
# Captures both [[Page]] and [[Page|Display text]], but only keeps "Page"
pattern = r"\[\[([^\]|#]+)(?:\|[^\]]+)?\]\]"

# Step 3: Extract raw links
raw_links = re.findall(pattern, text)

# Step 4: Clean: remove duplicates, strip whitespace
artist_links = sorted(set([link.strip() for link in raw_links]))

# Step 5: Remove unwanted links (categories, templates, etc.)
exclude_prefixes = (
    "Category:", "Template:", "File:", "Wikipedia:",
    "Help:", "Portal:", "Talk:", "Book:", "Draft:"
)

manual_excludes = [
    "AllMusic", "Rolling Stone", "rock music", "Heavy Metal", 
    "Punk Rock", "Alternative Rock", "Classic Rock", "singles",
    "album charts", "streaming", "downloads", "airplay"
]
artist_links = [
    link for link in artist_links
    if link not in manual_excludes and not link.startswith(exclude_prefixes)
]

print(f"Number of raw wiki-links found: {len(raw_links)}")
print(f"Number of unique cleaned artist links: {len(artist_links)}")
print("First 50 links before filtering:", artist_links[:30])
# Out:
# Number of raw wiki-links found: 492
# Number of unique cleaned artist links: 488
# First 50 links before filtering: ['10 Years (band)', '10cc', '3 Doors Down', '311 (band)', '38 Special (band)', 'A Perfect Circle', 'ABBA', 'AC/DC', 'AFI (band)', 'Accept (band)', 'Adam Ant', 'Aerosmith', 'Air Supply', 'Alanis Morissette', 'Alice Cooper', 'Alice Cooper (band)', 'Alice in Chains', 'Alter Bridge', 'Ambrosia (band)', 'America (band)', 'Anthrax (American band)', 'April Wine', 'Arcade Fire', 'Arctic Monkeys', 'Asia (band)', 'Audioslave', 'Avenged Sevenfold', 'Avril Lavigne', 'Awolnation', 'Bachman–Turner Overdrive']

# %%
# url = "https://raw.githubusercontent.com/adamajane/social-graphs-and-interactions-02805-assignments/refs/heads/main/assignment_1/Files/artists_graph_with_stats.gexf"

# # Fetch file from GitHub
# response = requests.get(url)
# response.raise_for_status()

# # Load into NetworkX
# G = nx.read_gexf(BytesIO(response.content))
# print(f"Loaded remote graph: {G.number_of_nodes()} nodes, {G.number_of_edges()} edges")
# Out:
# Loaded remote graph: 484 nodes, 7328 edges
